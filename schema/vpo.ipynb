# %%
import requests
import os
from dotenv import load_dotenv
from modules.get_token import get_token
load_dotenv()
start_url = os.getenv("PRJ_START_URL")

# %%
query = """
    query {
      __type(name: "purchaseorder") {
        fields(includeDeprecated: false) {
          name
          type {
            name
            kind
          }
        }
      }
    }
    """



headers = {
    "content-type": "application/json"
}
token = get_token()
url = f"{start_url}/graphql?token={token}"
res = requests.post(url, headers=headers, json={"query": query})
print(res.json())
# Out:
# {'data': {'__type': {'fields': [{'name': 'billingInformation', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'bulkImportId', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'confirmationNumber', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'contact', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'copiedFrom', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'copiedTime', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'cost', 'type': {'kind': 'SCALAR', 'name': 'Float'}}, {'name': 'createdBy', 'type': {'kind': 'OBJECT', 'name': 'User'}}, {'name': 'createdByPlainText', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'createdTime', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'currency', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'currencyLocale', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'date', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'dollarsOutstanding', 'type': {'kind'
# ...

# %%
query = """
    query {
      __type(name: "Invoice") {
        fields(includeDeprecated: false) {
          name
          type {
            name
            kind
          }
        }
      }
    }
    """

headers = {
    "content-type": "application/json"
}
token = get_token()
url = f"{start_url}/graphql?token={token}"
res = requests.post(url, headers=headers, json={"query": query})
print(res.json())
# Out:
# {'data': {'__type': {'fields': [{'name': 'bulkImportId', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'clientPartNumber', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'clientPoNum', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'copiedFrom', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'copiedTime', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'createdTime', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'currency', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'currencyLocale', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'customerPO', 'type': {'kind': 'OBJECT', 'name': 'CustomerPO'}}, {'name': 'customerPOPlainText', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'dateIssued', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'discount', 'type': {'kind': 'SCALAR', 'name': 'Float'}}, {'name': 'editLog', 'type': {'kind': 'OBJECT', 'name': 'EditLog'}}, {'name': 'editLogPlainText', 'type':
# ...

# %%
print("COTS query")

{'data': {'__type': {'fields': [{'name': 'adhesiveType', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'aka', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'amps', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'application', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'approvedBrands', 'type': {'kind': 'NON_NULL', 'name': None}}, 
                                {'name': 'bearingType', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'bondType', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'bulkImportId', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'coating', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'cogsAccount', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'connectorType', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'copiedFrom', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'copiedTime', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'createdBy', 'type': {'kind': 'OBJECT', 'name': 'User'}}, 
                                {'name': 'createdByApplication', 'type': {'kind': 'OBJECT', 'name': 'Authorization'}}, 
                                {'name': 'createdByPlainText', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'createdTime', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'cureType', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'defaultSaleLikelihoodPercent', 'type': {'kind': 'SCALAR', 'name': 'Float'}}, 
                                {'name': 'defaultSerializationPrefix', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'defaultSerializationSuffix', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'description', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'descriptionForSales', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'dollarsInInventory', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'driveType', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'editLog', 'type': {'kind': 'OBJECT', 'name': 'EditLog'}}, 
                                {'name': 'editLogPlainText', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'excludeFromInventoryEvaluation', 'type': {'kind': 'SCALAR', 'name': 'Boolean'}}, 
                                {'name': 'gage', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'groundZeroVerified', 'type': {'kind': 'SCALAR', 'name': 'Boolean'}}, 
                                {'name': 'groundZeroVerifiedBy', 'type': {'kind': 'OBJECT', 'name': 'User'}}, 
                                {'name': 'groundZeroVerifiedByPlainText', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'groundZeroVerifiedDate', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'hardness', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'hardnessScale', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'headType', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'height', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'idThreadLength', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'idThreadSize', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'ignoreSuggestedBOMAllocations', 'type': {'kind': 'SCALAR', 'name': 'Boolean'}}, 
                                {'name': 'insertIDThread', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'insertODThread', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'insertType', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'inspectionCertified', 'type': {'kind': 'SCALAR', 'name': 'Boolean'}}, {'name': 'installGroup', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'internalDiameter', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'inventoryAccount', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'inventoryImportValueTotal', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'inventoryQuantity', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'isArchived', 'type': {'kind': 'SCALAR', 'name': 'Boolean'}}, {'name': 'isSerialized', 'type': {'kind': 'SCALAR', 'name': 'Boolean'}}, {'name': 'isTemplate', 'type': {'kind': 'SCALAR', 'name': 'Boolean'}}, {'name': 'itemMustBeCertified', 'type': {'kind': 'SCALAR', 'name': 'Boolean'}}, {'name': 'lastModifiedBy', 'type': {'kind': 'OBJECT', 'name': 'User'}}, {'name': 'lastModifiedByApplication', 'type': {'kind': 'OBJECT', 'name': 'Authorization'}}, 
                                {'name': 'lastModifiedByPlainText', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'lastModifiedTime', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'leastAmountToOrder', 'type': {'kind': 'SCALAR', 'name': 'Float'}}, {'name': 'leftoverParts', 'type': {'kind': 'NON_NULL', 'name': None}}, {'name': 'legacyId', 'type': {'kind': 'NON_NULL', 'name': None}}, {'name': 'length', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'location', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'lockingElement', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'material', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'materialSpec', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'minimumQuantityOnHand', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'minReorderPoint', 'type': {'kind': 'SCALAR', 'name': 'Int'}}, {'name': 'mountingType', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'number', 'type': {'kind': 'SCALAR', 'name': 'Int'}}, {'name': 'oal', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'od', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'odSize', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'ohms', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'originalSortPosition', 'type': {'kind': 'SCALAR', 'name': 'Int'}}, {'name': 'otsId', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'outSerializationNumber', 'type': {'kind': 'SCALAR', 'name': 'Int'}}, {'name': 'part', 'type': {'kind': 'OBJECT', 'name': 'Part'}}, {'name': 'partPlainText', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'pictures', 'type': {'kind': 'LIST', 'name': None}}, {'name': 'pinStyle', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'powerSupply', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'proshopUrl', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'purchasingNotes', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'qtyAvailable', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'qtyOnOrder', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'quantity', 'type': {'kind': 'SCALAR', 'name': 'Float'}}, {'name': 'reliefType', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'remainingInventoryCost', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'resourceFiles', 'type': {'kind': 'LIST', 'name': None}}, {'name': 'rpm', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'salesAccount', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'sealed', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'serializationNumber', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'shelfLifeControlled', 'type': {'kind': 'SCALAR', 'name': 'Boolean'}}, {'name': 'shoulderDiameter', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'shoulderThickness', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'subclass', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'suggestedMaximumQuantity', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'taxType', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'templateGroup', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'testAttribute', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'thread', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'threadLength', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'throwDistance', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'type', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'units', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'volts', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'wallThickness', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'watts', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'width', 'type': {'kind': 'SCALAR', 'name': 'String'}}]}}}
# Out:
# COTS query
# {'data': {'__type': {'fields': [{'name': 'adhesiveType',
#      'type': {'kind': 'SCALAR', 'name': 'String'}},
#     {'name': 'aka', 'type': {'kind': 'SCALAR', 'name': 'String'}},
#     {'name': 'amps', 'type': {'kind': 'SCALAR', 'name': 'String'}},
#     {'name': 'application', 'type': {'kind': 'SCALAR', 'name': 'String'}},
#     {'name': 'approvedBrands', 'type': {'kind': 'NON_NULL', 'name': None}},
#     {'name': 'bearingType', 'type': {'kind': 'SCALAR', 'name': 'String'}},
#     {'name': 'bondType', 'type': {'kind': 'SCALAR', 'name': 'String'}},
#     {'name': 'bulkImportId', 'type': {'kind': 'SCALAR', 'name': 'String'}},
#     {'name': 'coating', 'type': {'kind': 'SCALAR', 'name': 'String'}},
#     {'name': 'cogsAccount', 'type': {'kind': 'SCALAR', 'name': 'String'}},
#     {'name': 'connectorType', 'type': {'kind': 'SCALAR', 'name': 'String'}},
#     {'name': 'copiedFrom', 'type': {'kind': 'SCALAR', 'name': 'String'}},
# ...

# %%
#parts
{'data': {'__type': {'fields': [{'name': 'activePersonInCharge', 'type': {'kind': 'OBJECT', 'name': 'User'}}, 
                                {'name': 'activePersonInChargePlainText', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'activePlanner', 'type': {'kind': 'OBJECT', 'name': 'User'}}, 
                                {'name': 'activePlannerPlainText', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'approvedPrintPart', 'type': {'kind': 'OBJECT', 'name': 'Part'}}, 
                                {'name': 'approvedPrintPartPlainText', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'bagSize', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'boxSize', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'buildScenarios', 'type': {'kind': 'NON_NULL', 'name': None}}, 
                                {'name': 'bulkImportId', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'clientPartRev', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'cogsAccount', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'company', 'type': {'kind': 'OBJECT', 'name': 'Contact'}}, {'name': 'companyPlainText', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'copiedFrom', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'copiedTime', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'createdBy', 'type': {'kind': 'OBJECT', 'name': 'User'}}, {'name': 'createdByPlainText', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'createdTime', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'currentEstimate', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'currentFairMarketValue', 'type': {'kind': 'SCALAR', 'name': 'Float'}}, {'name': 'currentFairMarketValueBy', 'type': {'kind': 'OBJECT', 'name': 'User'}}, {'name': 'currentFairMarketValueByPlainText', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'currentFairMarketValueDate', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'customerPartNumber', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'defaultRouting', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'defaultSaleLikelihoodPercent', 'type': {'kind': 'SCALAR', 'name': 'Float'}}, {'name': 'defaultSerializationPrefix', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'defaultSerializationSuffix', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'discusxml', 'type': {'kind': 'OBJECT', 'name': 'FileWithMetadata'}}, {'name': 'dollarsInInventoryForPart', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'dollarsInInventoryForPartCapped', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'drawingInformation', 'type': {'kind': 'LIST', 'name': None}}, {'name': 'editLog', 'type': {'kind': 'OBJECT', 'name': 'EditLog'}}, {'name': 'editLogPlainText', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'estimatefolderpath', 'type': {'kind': 'OBJECT', 'name': 'FileWithMetadata'}}, {'name': 'estimateId', 'type': {'kind': 'OBJECT', 'name': 'Estimate'}}, {'name': 'estimateIdPlainText', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'family', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'fixtures', 'type': {'kind': 'NON_NULL', 'name': None}}, {'name': 'groundZeroVerified', 'type': {'kind': 'SCALAR', 'name': 'Boolean'}}, {'name': 'groundZeroVerifiedBy', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'groundZeroVerifiedDate', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'ignoreSuggestedAllocationsOnBOM', 'type': {'kind': 'SCALAR', 'name': 'Boolean'}}, {'name': 'installGroup', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'inventoryAccount', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'inventoryImportValueTotal', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'inventoryQtyForPart', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'isSerialized', 'type': {'kind': 'SCALAR', 'name': 'Boolean'}}, {'name': 'isTemplate', 'type': {'kind': 'SCALAR', 'name': 'Boolean'}}, {'name': 'itarControlled', 'type': {'kind': 'SCALAR', 'name': 'Boolean'}}, {'name': 'itarControlledBy', 'type': {'kind': 'OBJECT', 'name': 'User'}}, {'name': 'itarControlledByPlainText', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'itarControlledDate', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'lastActivityDate', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'lastModifiedBy', 'type': {'kind': 'OBJECT', 'name': 'User'}}, {'name': 'lastModifiedByPlainText', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'lastModifiedTime', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'leadTime', 'type': {'kind': 'SCALAR', 'name': 'Int'}}, {'name': 'leastAmountToOrder', 'type': {'kind': 'SCALAR', 'name': 'Int'}}, {'name': 'leftoverParts', 'type': {'kind': 'NON_NULL', 'name': None}}, {'name': 'legacyId', 'type': {'kind': 'NON_NULL', 'name': None}}, {'name': 'mainContact', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'materialSpecsCosts', 'type': {'kind': 'NON_NULL', 'name': None}}, {'name': 'minimumOrderQty', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'minimumQuantityOnHand', 'type': {'kind': 'SCALAR', 'name': 'Int'}}, {'name': 'minReorderPoint', 'type': {'kind': 'SCALAR', 'name': 'Int'}}, {'name': 'multiplierMarkup', 'type': {'kind': 'SCALAR', 'name': 'Float'}}, {'name': 'netInspectImportNotes', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'netinspectxml', 'type': {'kind': 'OBJECT', 'name': 'FileWithMetadata'}}, {'name': 'notes', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'operations', 'type': {'kind': 'NON_NULL', 'name': None}}, {'name': 'originalSortPosition', 'type': {'kind': 'SCALAR', 'name': 'Int'}}, {'name': 'packagingInstructions', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'partDescription', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'partDevelopment', 'type': {'kind': 'NON_NULL', 'name': None}}, {'name': 'partFiles', 'type': {'kind': 'OBJECT', 'name': 'PartFiles'}}, {'name': 'partName', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'partNumber', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'partStock', 'type': {'kind': 'NON_NULL', 'name': None}}, {'name': 'pictures', 'type': {'kind': 'OBJECT', 'name': 'PartPictures'}}, {'name': 'planningLevel', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'priceStructure', 'type': {'kind': 'NON_NULL', 'name': None}}, {'name': 'pricingNotes', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'printForApproval', 'type': {'kind': 'SCALAR', 'name': 'Boolean'}}, {'name': 'printForApprovalBy', 'type': {'kind': 'OBJECT', 'name': 'User'}}, {'name': 'printForApprovalByPlainText', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'proshopUrl', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'qtyInWip', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'salesAccount', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'sequencedetailparsefile', 'type': {'kind': 'OBJECT', 'name': 'FileWithMetadata'}}, {'name': 'shippingCost', 'type': {'kind': 'SCALAR', 'name': 'Float'}}, {'name': 'specialShippingInstructions', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'standardizedLaborClass', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'status', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'taxType', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'techContact', 'type': {'kind': 'OBJECT', 'name': 'User'}}, {'name': 'techContactPlainText', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'templateGroup', 'type': {'kind': 'SCALAR', 'name': 'String'}}, {'name': 'threeDimModel', 'type': {'kind': 'OBJECT', 'name': 'PartThreeDimModel'}}, {'name': 'tolerancesTable', 'type': {'kind': 'NON_NULL', 'name': None}}, {'name': 'universalProductCode', 'type': {'kind': 'SCALAR', 'name': 'String'}}, 
                                {'name': 'year', 'type': {'kind': 'SCALAR', 'name': 'String'}}]}}}
# Out:
# {'data': {'__type': {'fields': [{'name': 'activePersonInCharge',
#      'type': {'kind': 'OBJECT', 'name': 'User'}},
#     {'name': 'activePersonInChargePlainText',
#      'type': {'kind': 'SCALAR', 'name': 'String'}},
#     {'name': 'activePlanner', 'type': {'kind': 'OBJECT', 'name': 'User'}},
#     {'name': 'activePlannerPlainText',
#      'type': {'kind': 'SCALAR', 'name': 'String'}},
#     {'name': 'approvedPrintPart', 'type': {'kind': 'OBJECT', 'name': 'Part'}},
#     {'name': 'approvedPrintPartPlainText',
#      'type': {'kind': 'SCALAR', 'name': 'String'}},
#     {'name': 'bagSize', 'type': {'kind': 'SCALAR', 'name': 'String'}},
#     {'name': 'boxSize', 'type': {'kind': 'SCALAR', 'name': 'String'}},
#     {'name': 'buildScenarios', 'type': {'kind': 'NON_NULL', 'name': None}},
#     {'name': 'bulkImportId', 'type': {'kind': 'SCALAR', 'name': 'String'}},
#     {'name': 'clientPartRev', 'type': {'kind': 'SCALAR', 'name': 'String'}},
# ...
